# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib qt

# %%
# print(dA_lump.shape, s7055_dl.shape, s7055_midpt.shape)
# Out:
# 0.00026953334903351674

# %%
# Out:
# 2.9925897266637286e-08

# %%
# # C Section Spar
# spar_thickness = 5e4
# Ixx_spar_required = np.max(Ixx_required) - Ixx_skin
# print(f"Maximum Ixx Spar (Required) = {Ixx_spar_required:.3g} m^4")

# # Length of single Flange
# spar_flange_length = 0.08
# spar_web_height = airfoil_max_thickness

# Ixx_spar_web = spar_thickness*spar_web_height**3/12
# # Evaluated for single Flange
# Ixx_spar_flange = (spar_web_height/2)*spar_thickness**3/12 + (spar_flange_length*spar_thickness)*(spar_web_height/2)

# Ixx_spar = Ixx_spar_web + Ixx_spar_flange*2
# print(f"Ixx Spar (Available) = {Ixx_spar:.3g} m^4")

# %%
I_required = (M_root*airfoil_max_thickness/2)/(stress_yield/(n_fos*n_vn*n_fatigue*k_stress_conc_factor))

# %%
print(I_required)
# Out:
# 7.540370404411766e-07

# %%
stringer = np.array([0.1, 0.6, 0.8])
chord_Stringer = stringer*0.265

# %%
print(chord_Stringer)
# Out:
# [0.0265 0.159  0.212 ]
