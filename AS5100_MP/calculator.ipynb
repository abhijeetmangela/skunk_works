# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
g = 9.81
rho_SL = 1.225

# %%
W_MaxTakeOff = 6.9*g
CL_Wing_Max = 1.05
S = 0.53

# %%
v_Stall = np.sqrt(W_MaxTakeOff/(0.5*rho_SL*S*CL_Wing_Max))

# %%
# Out:
# 14.092025429405417
